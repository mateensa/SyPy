# %% [raw]
# Libs used are xlrd, openpyxl, lxml (for excel), sqlalchemy (for sql), BeautifulSoup4 for (html)

# %%
import pandas as pd

# %%
df = pd.read_csv("C://Users//ms47807//Documents//Purchase_Agreements__Copy_F.csv")

# %%
df.to_csv("C://Users//ms47807//Documents//my_output", index=False)

# %%
pd.read_csv("C://Users//ms47807//Documents//my_output")
# Out:
#    5000117
# 5013518
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 2007/10/07 00:00:00.000000000
# 12603042
# 56374
# SCOPE TECHNOLOGY CO.  \
# 0   5000117
# 5013518
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 1   5000117
# 5013518
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 2   5000117
# 5013518
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 3   5000117
# 5013518
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 4   5000117
# 5013518
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 5   5000117
# 5013548
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 6   5000117
# 5013548
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 7   5000117
# 5013548
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 8   5000117
# 5013548
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 9   5000117
# 5013548
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 10  5000117
# 5013548
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 11  5000117
# 5013548
# 82
# SZLT OU
# 675018927
# 43
# GPA
# 20...
# 12  5000117
# ...

# %%
df2 =  pd.read_excel("sample-file.xlsx", sheetname="Sheet1")

# %%
df2.to_excel("excel_output.xlsx", sheet_name="SheetOne")

# %%
import pandas as pd
pd.read_html("https://www.fdic.gov/bank/individual/failed/banklist.html")
# Out:
# [                                             Bank Name                City  \
#  0      The Farmers and Merchants State Bank of Argonia             Argonia
#  1                                  Fayette County Bank          Saint Elmo
#  2    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
#  3                                       First NBC Bank         New Orleans
#  4                                        Proficio Bank  Cottonwood Heights
#  5                        Seaway Bank and Trust Company             Chicago
#  6                               Harvest Community Bank          Pennsville
#  7                                          Allied Bank            Mulberry
#  8                         The Woodbury Banking Company            Woodbury
#  9                               First CornerStone Bank     King of Prussia
#  10                                  Trust Company Bank             Memphis
# ...

# %%
html_link = "http://jobcard.zensar.com/eJobCard/monthlyAttendanceReportAction.do?method=getMonthlyAttendance"

# %%
pd.read_html(html_link)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-e9a56bc14025> in <module>()
# ----> 1 pd.read_html(html_link)
#
# d:\python\python36\lib\site-packages\pandas\io\html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na)
#     904                   thousands=thousands, attrs=attrs, encoding=encoding,
#     905                   decimal=decimal, converters=converters, na_values=na_values,
# --> 906                   keep_default_na=keep_default_na)
#
# d:\python\python36\lib\site-packages\pandas\io\html.py in _parse(flavor, io, match, attrs, encoding, **kwargs)
#     741             break
#     742     else:
# --> 743         raise_with_traceback(retained)
#     744
#     745     ret = []
#
# ...
